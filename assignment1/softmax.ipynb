# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.332581
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*
# As the values of W are so close to zero and normal distributed, we can expect that the scores out $w^{T} X_i$ is close to each other, so the loss will be close to -log(1/10), i.e. -log(1.0)

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 2.766755 analytic: 2.766755, relative error: 2.351376e-09
# numerical: 2.484920 analytic: 2.484920, relative error: 1.839452e-08
# numerical: 1.770230 analytic: 1.770230, relative error: 7.601890e-09
# numerical: 3.280882 analytic: 3.280882, relative error: 1.270168e-09
# numerical: 1.364411 analytic: 1.364411, relative error: 8.158223e-09
# numerical: -0.543511 analytic: -0.543512, relative error: 5.022652e-08
# numerical: -1.799015 analytic: -1.799015, relative error: 3.323075e-09
# numerical: 0.662329 analytic: 0.662329, relative error: 1.113390e-07
# numerical: 0.763594 analytic: 0.763594, relative error: 4.645620e-09
# numerical: 0.618275 analytic: 0.618275, relative error: 5.914768e-08
# numerical: 1.453256 analytic: 1.453256, relative error: 4.572195e-08
# numerical: -3.142667 analytic: -3.142667, relative error: 3.796918e-09
# numerical: 1.752333 analytic: 1.752333, relative error: 2.517709e-08
# numerical: 0.000522 analytic: 0.000522, relative error: 1.831422e-05
# numerical: 0.729164 analytic: 0.729164, relative error: 4.984989e-08
# numerical: -0.271341 analytic: -0.271341, relative error: 1.260537e-07
# numerical: -0.634187 analytic: -0.634187, relative error: 2.824899e-08
# numerical: -1.707700 analytic: -1.707700, relative error: 7.332494e-09
# numerical: -2.145567 analytic: -2.145567, relative error: 6.706714e-09
# numerical: 2.103138 analytic: 2.103138, relative error: 1.771603e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.332581e+00 computed in 0.147233s
#
# vectorized loss: 2.332581e+00 computed in 0.004410s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 3e-7]
regularization_strengths = [1.5e4, 3e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in np.linspace(*learning_rates, 5):
    for reg in np.linspace(*regularization_strengths, 5):
        tmp_softmax = Softmax()
        loss_ls = tmp_softmax.train(X_train, y_train, learning_rate=lr, reg=reg, num_iters=700, batch_size=200, verbose=True)

        y_pred_train = tmp_softmax.predict(X_train)
        train_acc = np.mean(y_pred_train == y_train)
        y_pred_val = tmp_softmax.predict(X_val)
        val_acc = np.mean(y_pred_val == y_val)

        results[(lr, reg)] = (train_acc, val_acc)
        print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_acc, val_acc))

        if val_acc > best_val :
            best_val = val_acc
            best_softmax = tmp_softmax
        # break
    # break

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 700: loss 468.209945
# iteration 100 / 700: loss 256.034420
# iteration 200 / 700: loss 140.885615
# iteration 300 / 700: loss 77.871497
# iteration 400 / 700: loss 43.629957
# iteration 500 / 700: loss 24.794952
# iteration 600 / 700: loss 14.475028
# lr 1.000000e-07 reg 1.500000e+04 train accuracy: 0.321163 val accuracy: 0.328000
# iteration 0 / 700: loss 582.346759
# iteration 100 / 700: loss 274.390906
# iteration 200 / 700: loss 130.025371
# iteration 300 / 700: loss 62.248988
# iteration 400 / 700: loss 30.510261
# iteration 500 / 700: loss 15.351338
# iteration 600 / 700: loss 8.329500
# lr 1.000000e-07 reg 1.875000e+04 train accuracy: 0.327673 val accuracy: 0.347000
# iteration 0 / 700: loss 700.563893
# iteration 100 / 700: loss 284.297815
# iteration 200 / 700: loss 116.283843
# iteration 300 / 700: loss 48.367440
# iteration 400 / 700: loss 20.782593
# iteration 500 / 700: loss 9.679587
# iteration 600 / 700: loss 5.087029
# lr 1.000000e-07 reg 2.250000e+04 train accuracy: 0.324245 val accuracy: 0.335000
# iteration 0 / 700: loss 814.385262
# iteration 100 / 700: loss 284.364851
# iteration 200 / 700: loss 100.233626
# iteration 300 / 700: loss 36.215440
# iteration 400 / 700: loss 13.984714
# iteration 500 / 700: loss 6.259713
# iteration 600 / 700: loss 3.638512
# lr 1.000000e-07 reg 2.625000e+04 train accuracy: 0.329490 val accuracy: 0.341000
# iteration 0 / 700: loss 925.951499
# iteration 100 / 700: loss 278.367462
# iteration 200 / 700: loss 84.709585
# iteration 300 / 700: loss 26.913423
# iteration 400 / 700: loss 9.572051
# iteration 500 / 700: loss 4.299318
# iteration 600 / 700: loss 2.752639
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.314286 val accuracy: 0.335000
# iteration 0 / 700: loss 464.671196
# iteration 100 / 700: loss 188.097474
# iteration 200 / 700: loss 77.267248
# iteration 300 / 700: loss 32.429120
# iteration 400 / 700: loss 14.339766
# iteration 500 / 700: loss 7.032754
# iteration 600 / 700: loss 4.056316
# lr 1.500000e-07 reg 1.500000e+04 train accuracy: 0.344429 val accuracy: 0.356000
# iteration 0 / 700: loss 578.867806
# iteration 100 / 700: loss 187.597089
# iteration 200 / 700: loss 61.956491
# iteration 300 / 700: loss 21.324289
# iteration 400 / 700: loss 8.250352
# iteration 500 / 700: loss 4.068270
# iteration 600 / 700: loss 2.669608
# lr 1.500000e-07 reg 1.875000e+04 train accuracy: 0.338816 val accuracy: 0.339000
# iteration 0 / 700: loss 700.612096
# iteration 100 / 700: loss 181.167238
# iteration 200 / 700: loss 48.169619
# iteration 300 / 700: loss 14.009405
# iteration 400 / 700: loss 5.147744
# iteration 500 / 700: loss 2.837156
# iteration 600 / 700: loss 2.236364
# lr 1.500000e-07 reg 2.250000e+04 train accuracy: 0.332918 val accuracy: 0.345000
# iteration 0 / 700: loss 797.257659
# iteration 100 / 700: loss 164.811507
# iteration 200 / 700: loss 35.438489
# iteration 300 / 700: loss 8.853088
# iteration 400 / 700: loss 3.512078
# iteration 500 / 700: loss 2.365544
# iteration 600 / 700: loss 2.156395
# lr 1.500000e-07 reg 2.625000e+04 train accuracy: 0.327347 val accuracy: 0.338000
# iteration 0 / 700: loss 929.986773
# iteration 100 / 700: loss 153.329643
# iteration 200 / 700: loss 26.771929
# iteration 300 / 700: loss 6.116800
# iteration 400 / 700: loss 2.765885
# iteration 500 / 700: loss 2.235704
# iteration 600 / 700: loss 2.159101
# lr 1.500000e-07 reg 3.000000e+04 train accuracy: 0.326082 val accuracy: 0.343000
# iteration 0 / 700: loss 461.355436
# iteration 100 / 700: loss 138.804246
# iteration 200 / 700: loss 42.796605
# iteration 300 / 700: loss 14.235839
# iteration 400 / 700: loss 5.750456
# iteration 500 / 700: loss 3.129689
# iteration 600 / 700: loss 2.425557
# lr 2.000000e-07 reg 1.500000e+04 train accuracy: 0.340061 val accuracy: 0.363000
# iteration 0 / 700: loss 588.027551
# iteration 100 / 700: loss 130.884799
# iteration 200 / 700: loss 30.499504
# iteration 300 / 700: loss 8.309708
# iteration 400 / 700: loss 3.500222
# iteration 500 / 700: loss 2.292146
# iteration 600 / 700: loss 2.154988
# lr 2.000000e-07 reg 1.875000e+04 train accuracy: 0.339020 val accuracy: 0.356000
# iteration 0 / 700: loss 708.040162
# iteration 100 / 700: loss 116.916065
# iteration 200 / 700: loss 20.764635
# iteration 300 / 700: loss 5.146806
# iteration 400 / 700: loss 2.596296
# iteration 500 / 700: loss 2.147610
# iteration 600 / 700: loss 2.083870
# lr 2.000000e-07 reg 2.250000e+04 train accuracy: 0.331694 val accuracy: 0.348000
# iteration 0 / 700: loss 817.669165
# iteration 100 / 700: loss 100.006723
# iteration 200 / 700: loss 13.894356
# iteration 300 / 700: loss 3.455500
# iteration 400 / 700: loss 2.279694
# iteration 500 / 700: loss 2.100737
# iteration 600 / 700: loss 2.121794
# lr 2.000000e-07 reg 2.625000e+04 train accuracy: 0.330612 val accuracy: 0.346000
# iteration 0 / 700: loss 926.875853
# iteration 100 / 700: loss 84.118838
# iteration 200 / 700: loss 9.371492
# iteration 300 / 700: loss 2.710576
# iteration 400 / 700: loss 2.176339
# iteration 500 / 700: loss 2.093876
# iteration 600 / 700: loss 2.095182
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.316245 val accuracy: 0.330000
# iteration 0 / 700: loss 462.603294
# iteration 100 / 700: loss 103.099860
# iteration 200 / 700: loss 24.283567
# iteration 300 / 700: loss 6.957083
# iteration 400 / 700: loss 3.202067
# iteration 500 / 700: loss 2.307351
# iteration 600 / 700: loss 2.112429
# lr 2.500000e-07 reg 1.500000e+04 train accuracy: 0.348857 val accuracy: 0.356000
# iteration 0 / 700: loss 592.176304
# iteration 100 / 700: loss 91.062126
# iteration 200 / 700: loss 15.524838
# iteration 300 / 700: loss 4.115596
# iteration 400 / 700: loss 2.400608
# iteration 500 / 700: loss 2.072968
# iteration 600 / 700: loss 2.102120
# lr 2.500000e-07 reg 1.875000e+04 train accuracy: 0.329388 val accuracy: 0.345000
# iteration 0 / 700: loss 704.601092
# iteration 100 / 700: loss 74.585460
# iteration 200 / 700: loss 9.562442
# iteration 300 / 700: loss 2.808896
# iteration 400 / 700: loss 2.159416
# iteration 500 / 700: loss 2.108530
# iteration 600 / 700: loss 2.104200
# lr 2.500000e-07 reg 2.250000e+04 train accuracy: 0.324816 val accuracy: 0.338000
# iteration 0 / 700: loss 822.286067
# iteration 100 / 700: loss 60.026678
# iteration 200 / 700: loss 6.167194
# iteration 300 / 700: loss 2.428511
# iteration 400 / 700: loss 2.088164
# iteration 500 / 700: loss 2.160567
# iteration 600 / 700: loss 2.083695
# lr 2.500000e-07 reg 2.625000e+04 train accuracy: 0.323571 val accuracy: 0.341000
# iteration 0 / 700: loss 933.296582
# iteration 100 / 700: loss 47.106897
# iteration 200 / 700: loss 4.263489
# iteration 300 / 700: loss 2.218729
# iteration 400 / 700: loss 2.128458
# iteration 500 / 700: loss 2.097098
# iteration 600 / 700: loss 2.184950
# lr 2.500000e-07 reg 3.000000e+04 train accuracy: 0.317061 val accuracy: 0.333000
# iteration 0 / 700: loss 468.501186
# iteration 100 / 700: loss 77.481940
# iteration 200 / 700: loss 14.245619
# iteration 300 / 700: loss 4.055510
# iteration 400 / 700: loss 2.335196
# iteration 500 / 700: loss 2.135946
# iteration 600 / 700: loss 2.028994
# lr 3.000000e-07 reg 1.500000e+04 train accuracy: 0.347327 val accuracy: 0.350000
# iteration 0 / 700: loss 579.938547
# iteration 100 / 700: loss 61.504148
# iteration 200 / 700: loss 8.189242
# iteration 300 / 700: loss 2.693518
# iteration 400 / 700: loss 2.072791
# iteration 500 / 700: loss 2.109987
# iteration 600 / 700: loss 2.038008
# lr 3.000000e-07 reg 1.875000e+04 train accuracy: 0.342694 val accuracy: 0.352000
# iteration 0 / 700: loss 677.111983
# iteration 100 / 700: loss 46.183518
# iteration 200 / 700: loss 5.001572
# iteration 300 / 700: loss 2.237188
# iteration 400 / 700: loss 2.073419
# iteration 500 / 700: loss 2.039584
# iteration 600 / 700: loss 2.095440
# lr 3.000000e-07 reg 2.250000e+04 train accuracy: 0.332000 val accuracy: 0.354000
# iteration 0 / 700: loss 796.284958
# iteration 100 / 700: loss 34.999137
# iteration 200 / 700: loss 3.461754
# iteration 300 / 700: loss 2.083051
# iteration 400 / 700: loss 2.070937
# iteration 500 / 700: loss 2.056578
# iteration 600 / 700: loss 2.144818
# lr 3.000000e-07 reg 2.625000e+04 train accuracy: 0.322531 val accuracy: 0.342000
# iteration 0 / 700: loss 931.902282
# iteration 100 / 700: loss 26.501692
# iteration 200 / 700: loss 2.727009
# iteration 300 / 700: loss 2.119943
# iteration 400 / 700: loss 2.063238
# iteration 500 / 700: loss 2.115524
# iteration 600 / 700: loss 2.095237
# lr 3.000000e-07 reg 3.000000e+04 train accuracy: 0.314653 val accuracy: 0.332000
# lr 1.000000e-07 reg 1.500000e+04 train accuracy: 0.321163 val accuracy: 0.328000
# lr 1.000000e-07 reg 1.875000e+04 train accuracy: 0.327673 val accuracy: 0.347000
# lr 1.000000e-07 reg 2.250000e+04 train accuracy: 0.324245 val accuracy: 0.335000
# lr 1.000000e-07 reg 2.625000e+04 train accuracy: 0.329490 val accuracy: 0.341000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.314286 val accuracy: 0.335000
# lr 1.500000e-07 reg 1.500000e+04 train accuracy: 0.344429 val accuracy: 0.356000
# lr 1.500000e-07 reg 1.875000e+04 train accuracy: 0.338816 val accuracy: 0.339000
# lr 1.500000e-07 reg 2.250000e+04 train accuracy: 0.332918 val accuracy: 0.345000
# lr 1.500000e-07 reg 2.625000e+04 train accuracy: 0.327347 val accuracy: 0.338000
# lr 1.500000e-07 reg 3.000000e+04 train accuracy: 0.326082 val accuracy: 0.343000
# lr 2.000000e-07 reg 1.500000e+04 train accuracy: 0.340061 val accuracy: 0.363000
# lr 2.000000e-07 reg 1.875000e+04 train accuracy: 0.339020 val accuracy: 0.356000
# lr 2.000000e-07 reg 2.250000e+04 train accuracy: 0.331694 val accuracy: 0.348000
# lr 2.000000e-07 reg 2.625000e+04 train accuracy: 0.330612 val accuracy: 0.346000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.316245 val accuracy: 0.330000
# lr 2.500000e-07 reg 1.500000e+04 train accuracy: 0.348857 val accuracy: 0.356000
# lr 2.500000e-07 reg 1.875000e+04 train accuracy: 0.329388 val accuracy: 0.345000
# lr 2.500000e-07 reg 2.250000e+04 train accuracy: 0.324816 val accuracy: 0.338000
# lr 2.500000e-07 reg 2.625000e+04 train accuracy: 0.323571 val accuracy: 0.341000
# lr 2.500000e-07 reg 3.000000e+04 train accuracy: 0.317061 val accuracy: 0.333000
# lr 3.000000e-07 reg 1.500000e+04 train accuracy: 0.347327 val accuracy: 0.350000
# lr 3.000000e-07 reg 1.875000e+04 train accuracy: 0.342694 val accuracy: 0.352000
# lr 3.000000e-07 reg 2.250000e+04 train accuracy: 0.332000 val accuracy: 0.354000
# lr 3.000000e-07 reg 2.625000e+04 train accuracy: 0.322531 val accuracy: 0.342000
# lr 3.000000e-07 reg 3.000000e+04 train accuracy: 0.314653 val accuracy: 0.332000
# best validation accuracy achieved during cross-validation: 0.363000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.354000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
# True
#
# $\color{blue}{\textit Your Explanation:}$
# For SVM, there is a margin makes sure the minor change in scores might not change the total loss;
# But for Softmax, minor change in scores will turns to change the prediction destribution and change the total loss

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
